# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhikarlekar17/Data_Science_Lab_SE_A__26/blob/main/ds_prac_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
data = np.random.normal(0, 1, 1000)

plt.hist(data, bins=30, density=True)

x = np.linspace(min(data), max(data), 100)
plt.plot(x, norm.pdf(x, 0, 1))

plt.title("Normal Distribution")
plt.show()

# %%
data = np.array([10, 20, 30, 40, 50])

print("Mean:", np.mean(data))
print("Median:", np.median(data))
print("Variance:", np.var(data))
print("Std Dev:", np.std(data))
# Out:
# Mean: 30.0
# Median: 30.0
# Variance: 200.0
# Std Dev: 14.142135623730951

# %%
tosses = np.random.choice([0, 1], size=1000)

heads = np.sum(tosses == 1)
tails = np.sum(tosses == 0)

print("Heads:", heads)
print("Tails:", tails)
print("Probability of Heads:", heads/1000)
print("Probability of Tails:", tails/1000)
# Out:
# Heads: 514
# Tails: 486
# Probability of Heads: 0.514
# Probability of Tails: 0.486
